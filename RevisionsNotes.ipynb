# %%
import pandas as pd

# %%
ecom = pd.read_csv("ecommerce.csv", parse_dates = (['order_date', 'delivery_date']))

# %%
ecom.set_index("ID")
# Out:
#     order_date delivery_date
# ID
# 1   1998-05-24    1999-02-05
# 2   1992-04-22    1998-03-06
# 4   1991-02-10    1992-08-26
# 5   1992-07-21    1997-11-20
# 7   1993-09-02    1998-06-10
# ..         ...           ...
# 990 1991-06-24    1996-02-02
# 991 1991-09-09    1998-03-30
# 993 1990-11-16    1998-04-27
# 994 1993-06-03    1993-06-13
# 997 1990-01-04    1991-10-03
#
# [501 rows x 2 columns]

# %%
ecom['time to deliver'] = ecom['delivery_date'] - ecom['order_date']

# %%
ecom
# Out:
#       ID order_date delivery_date time to deliver
# 0      1 1998-05-24    1999-02-05        257 days
# 1      2 1992-04-22    1998-03-06       2144 days
# 2      4 1991-02-10    1992-08-26        563 days
# 3      5 1992-07-21    1997-11-20       1948 days
# 4      7 1993-09-02    1998-06-10       1742 days
# ..   ...        ...           ...             ...
# 496  990 1991-06-24    1996-02-02       1684 days
# 497  991 1991-09-09    1998-03-30       2394 days
# 498  993 1990-11-16    1998-04-27       2719 days
# 499  994 1993-06-03    1993-06-13         10 days
# 500  997 1990-01-04    1991-10-03        637 days
#
# [501 rows x 4 columns]

# %%
ecom[ecom['time to deliver'] > '300 days']
# Out:
#       ID order_date delivery_date time to deliver
# 1      2 1992-04-22    1998-03-06       2144 days
# 2      4 1991-02-10    1992-08-26        563 days
# 3      5 1992-07-21    1997-11-20       1948 days
# 4      7 1993-09-02    1998-06-10       1742 days
# 6      9 1990-01-25    1994-10-02       1711 days
# ..   ...        ...           ...             ...
# 495  986 1990-12-10    1992-12-16        737 days
# 496  990 1991-06-24    1996-02-02       1684 days
# 497  991 1991-09-09    1998-03-30       2394 days
# 498  993 1990-11-16    1998-04-27       2719 days
# 500  997 1990-01-04    1991-10-03        637 days
#
# [410 rows x 4 columns]

# %%
import pandas as pd

# %%
bond = pd.read_csv("jamesbond.csv")

# %%
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
bond.loc[:2]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.loc[1:3]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
#
#    Budget  Bond Actor Salary
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7

# %%
bond.loc[bond.Budget > 5, ['Actor', 'Film']]
# Out:
#              Actor                             Film
# 0     Sean Connery                           Dr. No
# 1     Sean Connery            From Russia with Love
# 2     Sean Connery                       Goldfinger
# 3     Sean Connery                      Thunderball
# 4      David Niven                    Casino Royale
# 5     Sean Connery              You Only Live Twice
# 6   George Lazenby  On Her Majesty's Secret Service
# 7     Sean Connery             Diamonds Are Forever
# 8      Roger Moore                 Live and Let Die
# 9      Roger Moore      The Man with the Golden Gun
# 10     Roger Moore             The Spy Who Loved Me
# 11     Roger Moore                        Moonraker
# 12     Roger Moore               For Your Eyes Only
# 13    Sean Connery            Never Say Never Again
# 14     Roger Moore                        Octopussy
# 15     Roger Moore                 A View to a Kill
# 16  Timothy Dalton             The Living Daylights
# ...

# %%
A = rng.randint(10,(3,4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-875919a5e28a> in <module>
# ----> 1 A = rng.randint(10,(3,4))
#
# NameError: name 'rng' is not defined

# %%
import numpy as np

# %%
A = rng.randint(10, size = (3,4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-31927c9d8e1e> in <module>
# ----> 1 A = rng.randint(10, size = (3,4))
#
# NameError: name 'rng' is not defined

# %%
bond.rename(columns = {'Bond Actor Salary': 'Salary'}, inplace = True)

# %%
bond.loc[bond.Salary > 10, ['Film', 'Actor', 'Salary']]
# Out:
#                        Film           Actor  Salary
# 20  The World Is Not Enough  Pierce Brosnan    13.5
# 21          Die Another Day  Pierce Brosnan    17.9
# 24                  Skyfall    Daniel Craig    14.5

# %%
bond['Salary'].sum()
# Out:
# 123.3
