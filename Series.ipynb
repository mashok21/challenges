# %%
courses = ['maths', 'statistics', 'accounting', 'economics', 'business studies']

# %%
pd.Series(courses)
# Out:
# 0               maths
# 1          statistics
# 2          accounting
# 3           economics
# 4    business studies
# dtype: object

# %%
scores = [90, 99, 95, 80, 80]

# %%
score_measures = pd.Series(scores)

# %%
score_measures.sum()
# Out:
# 444

# %%
score_measures.mean()
# Out:
# 88.8

# %%
score_measures.product()
# Out:
# 5417280000

# %%
score_measures.keys
# Out:
# <bound method Series.keys of 0    90
# 1    99
# 2    95
# 3    80
# 4    80
# dtype: int64>

# %%
score_measures.values
# Out:
# array([90, 99, 95, 80, 80], dtype=int64)

# %%
google = pd.read_csv("Google_Stock_Price_Train.csv", usecols = ['Close'], squeeze = True)

# %%
google
# Out:
# 0       663.59
# 1       666.45
# 2       657.21
# 3       648.24
# 4       620.76
#          ...
# 1253    789.91
# 1254    791.55
# 1255    785.05
# 1256    782.79
# 1257    771.82
# Name: Close, Length: 1258, dtype: object

# %%
google = pd.read_csv("Google_Stock_Price_Train.csv", usecols = ['Close'], squeeze = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-944bbe0412a1> in <module>
# ----> 1 google = pd.read_csv("Google_Stock_Price_Train.csv", usecols = ['Close'], squeeze = True)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
google = pd.read_csv("Google_Stock_Price_Train.csv", usecols = ['Close'], squeeze = True)

# %%
google
# Out:
# 0       663.59
# 1       666.45
# 2       657.21
# 3       648.24
# 4       620.76
#          ...
# 1253    789.91
# 1254    791.55
# 1255    785.05
# 1256    782.79
# 1257    771.82
# Name: Close, Length: 1258, dtype: object

# %%
min(google)
# Out:
# '1,000.55'

# %%
sorted(google)
# Out:
# ['1,000.55',
#  '1,004.24',
#  '1,005.19',
#  '1,007.82',
#  '1,008.64',
#  '1,009.01',
#  '1,012.22',
#  '1,012.42',
#  '1,013.25',
#  '1,018.72',
#  '1,019.51',
#  '1,019.95',
#  '1,022.39',
#  '1,022.74',
#  '1,023.30',
#  '1,024.23',
#  '1,027.60',
#  '1,027.76',
#  '1,028.59',
#  '1,028.73',
#  '1,029.06',
#  '1,029.64',
#  '1,030.73',
#  '1,031.24',
#  '1,032.40',
#  '1,033.40',
#  '1,043.07',
#  '1,050.38',
#  '1,051.59',
#  '1,054.45',
#  '1,055.28',
#  '1,055.51',
#  '1,056.69',
#  '1,057.89',
#  '1,060.20',
#  '1,066.93',
#  '1,066.94',
#  '1,067.03',
#  '1,070.04',
#  '1,074.34',
#  '1,075.19',
#  '1,081.69',
#  '1,081.78',
#  '1,083.25',
#  '1,097.61',
#  '1,098.21',
#  '1,101.97',
#  '1,103.89',
#  '1,106.42',
#  '1,108.80',
#  '1,110.07',
#  '1,112.05',
#  '1,114.26',
#  '1,114.40',
#  '1,115.34',
#  '1,117.64',
#  '1,119.91',
#  '1,119.94',
#  '1,120.75',
#  '1,127.09',
#  '1,127.15',
#  '1,128.87',
#  '1,130.33',
#  '1,132.28',
#  '1,135.04',
#  '1,135.74',
# ...

# %%
sum(list(google))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f5bb989ba61c> in <module>
# ----> 1 sum(list(google))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
dict(google)
# Out:
# {0: '663.59',
#  1: '666.45',
#  2: '657.21',
#  3: '648.24',
#  4: '620.76',
#  5: '621.43',
#  6: '624.25',
#  7: '627.92',
#  8: '623.28',
#  9: '626.86',
#  10: '631.18',
#  11: '637.82',
#  12: '584.39',
#  13: '583.92',
#  14: '579.34',
#  15: '567.93',
#  16: '566.54',
#  17: '578.39',
#  18: '576.11',
#  19: '578.52',
#  20: '579.24',
#  21: '583.51',
#  22: '594.7',
#  23: '607.42',
#  24: '605.11',
#  25: '608.18',
#  26: '609.79',
#  27: '604.25',
#  28: '610.52',
#  29: '608.09',
#  30: '603.9',
#  31: '604.86',
#  32: '602.98',
#  33: '612.32',
#  34: '606.28',
#  35: '604.45',
#  36: '608.23',
#  37: '607.64',
#  38: '616.7',
#  39: '616.56',
#  40: '620.7',
#  41: '619.55',
#  42: '612.57',
#  43: '603.3',
#  44: '605.14',
#  45: '605.48',
#  46: '598.61',
#  47: '603.49',
#  48: '616.09',
#  49: '614.3',
#  50: '619.43',
#  51: '623.33',
#  52: '632.24',
#  53: '631.76',
#  54: '638.23',
#  55: '644.28',
#  56: '640.83',
#  57: '647.55',
#  58: '645.25',
# ...

# %%
google.index
# Out:
# RangeIndex(start=0, stop=1258, step=1)

# %%
dict(google)
# Out:
# {0: '663.59',
#  1: '666.45',
#  2: '657.21',
#  3: '648.24',
#  4: '620.76',
#  5: '621.43',
#  6: '624.25',
#  7: '627.92',
#  8: '623.28',
#  9: '626.86',
#  10: '631.18',
#  11: '637.82',
#  12: '584.39',
#  13: '583.92',
#  14: '579.34',
#  15: '567.93',
#  16: '566.54',
#  17: '578.39',
#  18: '576.11',
#  19: '578.52',
#  20: '579.24',
#  21: '583.51',
#  22: '594.7',
#  23: '607.42',
#  24: '605.11',
#  25: '608.18',
#  26: '609.79',
#  27: '604.25',
#  28: '610.52',
#  29: '608.09',
#  30: '603.9',
#  31: '604.86',
#  32: '602.98',
#  33: '612.32',
#  34: '606.28',
#  35: '604.45',
#  36: '608.23',
#  37: '607.64',
#  38: '616.7',
#  39: '616.56',
#  40: '620.7',
#  41: '619.55',
#  42: '612.57',
#  43: '603.3',
#  44: '605.14',
#  45: '605.48',
#  46: '598.61',
#  47: '603.49',
#  48: '616.09',
#  49: '614.3',
#  50: '619.43',
#  51: '623.33',
#  52: '632.24',
#  53: '631.76',
#  54: '638.23',
#  55: '644.28',
#  56: '640.83',
#  57: '647.55',
#  58: '645.25',
# ...

# %%
index(google)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-2d304fe8a744> in <module>
# ----> 1 index(google)
#
# NameError: name 'index' is not defined

# %%
index.google
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-96aaab07c0a3> in <module>
# ----> 1 index.google
#
# NameError: name 'index' is not defined

# %%
google.dtype
# Out:
# dtype('O')

# %%
google.is_unique
# Out:
# False

# %%
google.ndim
# Out:
# 1

# %%
google.shape
# Out:
# (1258,)

# %%
google.size
# Out:
# 1258

# %%
google.name = "microsoft"

# %%
microsoft
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-49e158b5e4e9> in <module>
# ----> 1 microsoft
#
# NameError: name 'microsoft' is not defined

# %%
google
# Out:
# 0       663.59
# 1       666.45
# 2       657.21
# 3       648.24
# 4       620.76
#          ...
# 1253    789.91
# 1254    791.55
# 1255    785.05
# 1256    782.79
# 1257    771.82
# Name: microsoft, Length: 1258, dtype: object

# %%
google.sort_values()
# Out:
# 452    1,000.55
# 453    1,004.24
# 465    1,005.19
# 467    1,007.82
# 451    1,008.64
#          ...
# 385      916.04
# 384      917.09
# 381      917.72
# 382      920.47
# 383      922.16
# Name: microsoft, Length: 1258, dtype: object

# %%
google.max
# Out:
# <bound method Series.max of 0       663.59
# 1       666.45
# 2       657.21
# 3       648.24
# 4       620.76
#          ...
# 1253    789.91
# 1254    791.55
# 1255    785.05
# 1256    782.79
# 1257    771.82
# Name: microsoft, Length: 1258, dtype: object>

# %%
google.sort_
