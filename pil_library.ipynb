# %%
from PIL import Image

# %%
mac = Image.open("example.jpg")

# %%
mac.size
# Out:
# (1993, 1257)

# %%
mac.filename
# Out:
# 'example.jpg'

# %%
mac.format
# Out:
# 'JPEG'

# %%
pencils = Image.open("pencils.jpg")

# %%
pencils.size
# Out:
# (1950, 1300)

# %%
pencils.format
# Out:
# 'JPEG'

# %%
pencils.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x1600DC23D08>

# %%
x = 0
y = 0
w = 1/3 * pencils.size[0]
h = .1 * pencils.size[1]

# %%
pencils.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=650x130 at 0x1600DC3A648>

# %%
x = 0
y = 1100
h = 1300
w = 1/3 * pencils.size[0]
pencils.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=650x200 at 0x1600DC41FC8>

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x1600DB97E88>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
x =  mac.size[0]
y = mac.size[1]

# %%
X = 1/2 * x - 200
Y = y - 500
W = 200
H = 400

# %%
pc = mac.crop((875,875,1125,1125))

# %%
mac.paste(im = pc, box = (1500,500))

# %%
mac.resize((500,500))
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x1600F7038C8>

# %%
words = Image.open("word_matrix.png")

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x16011B34188>

# %%
mask = Image.open("mask.png")

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x16011B29FC8>

# %%
wordsize = words.size

# %%
remask = mask.resize(wordsize)

# %%
remask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x16011B36E08>

# %%
remask.putalpha(200)

# %%
remask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x16011B36E08>

# %%
words.paste(im=remask, box=(0,0), mask=remask)

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x16011B34188>
