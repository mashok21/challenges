# %%
import pandas as pd

df = pd.read_csv('matches.csv')

# %%
len(df)
# Out:
# 636

# %%
df.head(3)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
df = df.drop(columns = ['id'])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-30f7eb7936d0> in <module>
# ----> 1 df = df.drop(columns = ['id'])
#       2 df
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
# df = df.sort_values(['season'])
# df = df.reset_index()
# # df = df.drop(columns = 'index')
# df

# %%
df.count()
# Out:
# index              636
# level_0            636
# season             636
# city               629
# date               636
# team1              636
# team2              636
# toss_winner        636
# toss_decision      636
# result             636
# dl_applied         636
# winner             633
# win_by_runs        636
# win_by_wickets     636
# player_of_match    633
# venue              636
# umpire1            635
# umpire2            635
# umpire3              0
# dtype: int64

# %%
df.head(1)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN

# %%
df['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
import re 

city_winner ={}

def win(x):
    if x not in city_winner:
        city_winner[x]=1
    else :
        city_winner[x]=city_winner[x]+1
# change_name('Bangalore')
df['winner'].apply(win)
print(city_winner).sort_value()
# Out:
# {'Sunrisers Hyderabad': 42, 'Rising Pune Supergiant': 10, 'Kolkata Knight Riders': 77, 'Kings XI Punjab': 70, 'Royal Challengers Bangalore': 73, 'Mumbai Indians': 92, 'Delhi Daredevils': 62, 'Gujarat Lions': 13, 'Chennai Super Kings': 79, 'Rajasthan Royals': 63, 'Deccan Chargers': 29, 'Pune Warriors': 12, 'Kochi Tuskers Kerala': 6, nan: 3, 'Rising Pune Supergiants': 5}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-49a3aab82723> in <module>
#      10 # change_name('Bangalore')
#      11 df['winner'].apply(win)
# ---> 12 print(city_winner).sort_value()
#      13
#
# AttributeError: 'NoneType' object has no attribute 'sort_value'

# %%
df = df.rename(columns={"team1": "Home_Team", "team2": "Away_Team"})
df
# Out:
#      season        city        date                    Home_Team  \
# 0      2008      Mumbai  2008-06-01          Chennai Super Kings
# 1      2008      Jaipur  2008-05-04          Chennai Super Kings
# 2      2008      Mumbai  2008-05-04               Mumbai Indians
# 3      2008  Chandigarh  2008-05-03              Kings XI Punjab
# 4      2008   Hyderabad  2008-05-25              Deccan Chargers
# 5      2008     Chennai  2008-05-02          Chennai Super Kings
# 6      2008      Jaipur  2008-05-01             Rajasthan Royals
# 7      2008   Hyderabad  2008-05-01              Deccan Chargers
# 8      2008       Delhi  2008-04-30             Delhi Daredevils
# 9      2008     Kolkata  2008-04-29        Kolkata Knight Riders
# 10     2008   Bengaluru  2008-04-28          Chennai Super Kings
# 11     2008  Chandigarh  2008-04-27             Delhi Daredevils
# 12     2008   Bengaluru  2008-05-05  Royal Challengers Bangalore
# ...

# %%
import pandas as pd

df = pd.read_csv('matches.csv')

def clean_season(season):
    season = str(season)
    season = season.strip()
    return season

df['season']= df['season'].apply(clean_season)

# %%
season = [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

df_1 = df

for i in season:
    df = df_1[df_1['season']==str(i)] #'2008'
    if len(df)>0:
        batting_first_win = df[df['win_by_runs']!=0]
        batting_second_win = df[df['win_by_runs']==0]
        match_count = len(df)

        bfw_count = len(batting_first_win)
        bsw_count = len(batting_second_win)

        bfw_win_percent = (bfw_count/match_count)*100
        bsw_win_percent = (bsw_count/match_count)*100

        print('season', i, 'batting first win %:', bfw_win_percent)
        print('season', i, 'batting second win %:', bsw_win_percent,'\n\n')
        
        continue
# Out:
# season 2008 batting first win %: 41.37931034482759
# season 2008 batting second win %: 58.620689655172406
#
#
# season 2009 batting first win %: 47.368421052631575
# season 2009 batting second win %: 52.63157894736842
#
#
# season 2010 batting first win %: 51.66666666666667
# season 2010 batting second win %: 48.333333333333336
#
#
# season 2011 batting first win %: 45.20547945205479
# season 2011 batting second win %: 54.794520547945204
#
#
# season 2012 batting first win %: 45.94594594594595
# season 2012 batting second win %: 54.054054054054056
#
#
# season 2013 batting first win %: 48.68421052631579
# season 2013 batting second win %: 51.31578947368421
#
#
# season 2014 batting first win %: 36.666666666666664
# season 2014 batting second win %: 63.33333333333333
#
#
# season 2015 batting first win %: 54.23728813559322
# season 2015 batting second win %: 45.76271186440678
#
#
# season 2016 batting first win %: 35.0
# season 2016 batting second win %: 65.0
#
#
# ...

# %%
df.season.unique()
# Out:
# array([], dtype=int64)

# %%
a.pivot_table(index='season', values='win_by_runs', aggfunc='mean', margins=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-910a86147261> in <module>
# ----> 1 a.pivot_table(index='season', values='win_by_runs', aggfunc='mean', margins=True)
#
# NameError: name 'a' is not defined

# %%
s2008 = df[df['season']== 2008]

# %%
len(s2008)
# Out:
# 58

# %%
x = df.pivot_table(index='city', values='date', aggfunc='count', margins=True)
x
# Out:
#                 date
# city
# Abu Dhabi          7
# Ahmedabad         12
# Bangalore         66
# Bengaluru         14
# Bloemfontein       2
# Cape Town          7
# Centurion         12
# Chandigarh        46
# Chennai           57
# Cuttack            7
# Delhi             74
# Dharamsala         9
# Durban            15
# East London        3
# Hyderabad         64
# Indore             9
# Jaipur            47
# Johannesburg       8
# Kanpur             4
# Kimberley          3
# Kochi              5
# Kolkata           77
# Mohali            10
# Mumbai           101
# Nagpur             3
# Port Elizabeth     7
# Pune              38
# Raipur             6
# Rajkot            10
# Ranchi             7
# Sharjah            6
# Visakhapatnam     13
# All              749

# %%
x.sort_values(by=['date'], ascending=False)
# Out:
#                 date
# city
# All              749
# Mumbai           101
# Kolkata           77
# Delhi             74
# Bangalore         66
# Hyderabad         64
# Chennai           57
# Jaipur            47
# Chandigarh        46
# Pune              38
# Durban            15
# Bengaluru         14
# Visakhapatnam     13
# Centurion         12
# Ahmedabad         12
# Mohali            10
# Rajkot            10
# Dharamsala         9
# Indore             9
# Johannesburg       8
# Ranchi             7
# Port Elizabeth     7
# Abu Dhabi          7
# Cuttack            7
# Cape Town          7
# Raipur             6
# Sharjah            6
# Kochi              5
# Kanpur             4
# Nagpur             3
# Kimberley          3
# East London        3
# Bloemfontein       2

# %%
x = len(df[df['toss_decision'] == 'bat'])
x/756
# Out:
# 0.38756613756613756

# %%
dd_h = df[df['team1']=='Delhi Daredevils']

dd_a = df[df['team2']=='Delhi Daredevils']

t_dd = len(dd_h) + len(dd_a)
t_dd
# Out:
# 161

# %%
print(len(dd_h))
len(dd_h[dd_h['winner']=='Delhi Daredevils'])
# Out:
# 72
# 25

# %%
h1 = len(rcb_h)
h = len(rcb_h[rcb_h['winner']=='Delhi Daredevils'])
r = (h/h1)*100
r
# Out:
# 33.33333333333333

# %%
a1 = len(rcb_a)
a = len(rcb_a[rcb_a['winner']=='Delhi Daredevils'])
r2 = (a/a1)*100
r2
# Out:
# 48.80952380952381
