# %%
import pandas as pd

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")

# %%
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")

# %%
customers = pd.read_csv("Restaurant - Customers.csv")

# %%
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
customers
# Out:
#        ID First Name Last Name  Gender       Company  \
# 0       1     Joseph   Perkins    Male       Dynazzy
# 1       2   Jennifer   Alvarez  Female          DabZ
# 2       3      Roger     Black    Male       Tagfeed
# 3       4     Steven     Evans    Male          Fatz
# 4       5       Judy  Morrison  Female       Demivee
# ..    ...        ...       ...     ...           ...
# 995   996      Debra    Garcia  Female  Dazzlesphere
# 996   997    Douglas    Bishop    Male      Livepath
# 997   998      Frank  Franklin    Male    Brainverse
# 998   999    Jessica     Burns  Female    Babbleblab
# 999  1000      Brian   Daniels    Male         Tazzy
#
#                         Occupation
# 0    Community Outreach Specialist
# 1          Senior Quality Engineer
# 2                Account Executive
# 3                 Registered Nurse
# 4                  Legal Assistant
# ..                             ...
# 995            Structural Engineer
# 996                    Developer I
# ...

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
foods.head(3)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99
# 2        3      Taco   2.99

# %%
len(week1)
# Out:
# 250

# %%
len(week2)
# Out:
# 250

# %%
pd.concat([week1,week2], ignore_index = True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 495          783       10
# 496          556       10
# 497          547        9
# 498          252        9
# 499          249        6
#
# [500 rows x 2 columns]

# %%
week2
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [250 rows x 2 columns]

# %%
week2.append(week1).tail(3)
# Out:
#      Customer ID  Food ID
# 247          134        3
# 248          396        6
# 249          535       10

# %%
week1.merge(week2, how = "inner", on = "Customer ID" , suffixes = [' - 1', ' - 2'])
# Out:
#     Customer ID  Food ID - 1  Food ID - 2
# 0           537            9            5
# 1           155            9            3
# 2           155            1            3
# 3           503            5            8
# 4           503            5            9
# ..          ...          ...          ...
# 57          945            5            4
# 58          343            3            5
# 59          343            3            2
# 60          343            3            7
# 61          621            9            6
#
# [62 rows x 3 columns]

# %%
week1[week1["Customer ID"] == 155]
# Out:
#     Customer ID  Food ID
# 4           155        9
# 17          155        1

# %%
week2[week2["Customer ID"] == 155]
# Out:
#      Customer ID  Food ID
# 208          155        3

# %%
week1.merge(week2, how = "inner", on = ["Customer ID", "Food ID"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
week1[week1["Customer ID"] == 578]
# Out:
#      Customer ID  Food ID
# 224          578        5

# %%
week2[week2["Customer ID"] == 578]
# Out:
#      Customer ID  Food ID
# 29           578        5
# 189          578        5

# %%
merged = week1.merge(week2, how = "outer", on = "Customer ID" , suffixes = [' - 1', ' - 2'], indicator = True)
merged
# Out:
#      Customer ID  Food ID - 1  Food ID - 2      _merge
# 0            537          9.0          5.0        both
# 1             97          4.0          NaN   left_only
# 2            658          1.0          NaN   left_only
# 3            202          2.0          NaN   left_only
# 4            155          9.0          3.0        both
# ..           ...          ...          ...         ...
# 449          855          NaN          4.0  right_only
# 450          559          NaN         10.0  right_only
# 451          276          NaN          4.0  right_only
# 452          556          NaN         10.0  right_only
# 453          252          NaN          9.0  right_only
#
# [454 rows x 4 columns]

# %%
merged["_merge"].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %%
merged[merged['_merge'].isin(["left_only", "right_only"])]
# Out:
#      Customer ID  Food ID - 1  Food ID - 2      _merge
# 1             97          4.0          NaN   left_only
# 2            658          1.0          NaN   left_only
# 3            202          2.0          NaN   left_only
# 6            213          8.0          NaN   left_only
# 7            600          1.0          NaN   left_only
# ..           ...          ...          ...         ...
# 449          855          NaN          4.0  right_only
# 450          559          NaN         10.0  right_only
# 451          276          NaN          4.0  right_only
# 452          556          NaN         10.0  right_only
# 453          252          NaN          9.0  right_only
#
# [392 rows x 4 columns]

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
foods.head(3)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99
# 2        3      Taco   2.99

# %%
week1.merge(foods, how = 'left', on = "Food ID")
# Out:
#      Customer ID  Food ID   Food Item  Price
# 0            537        9       Donut   0.99
# 1             97        4  Quesadilla   4.25
# 2            658        1       Sushi   3.99
# 3            202        2     Burrito   9.99
# 4            155        9       Donut   0.99
# ..           ...      ...         ...    ...
# 245          413        9       Donut   0.99
# 246          926        6       Pasta  13.99
# 247          134        3        Taco   2.99
# 248          396        6       Pasta  13.99
# 249          535       10       Drink   1.75
#
# [250 rows x 4 columns]

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
week2.merge(customers, how = "left", left_on = "Customer ID", right_on = "ID", sort = True).drop("ID", axis = 1)
# Out:
#      Customer ID  Food ID First Name Last Name  Gender        Company  \
# 0              8        6    Frances     Adams  Female       Dabshots
# 1             13        2       Ruth   Alvarez  Female    Twitterlist
# 2             21        4     Albert     Burns    Male      Rhynoodle
# 3             24        8      Donna    Thomas  Female        Jaxbean
# 4             27        4    Jessica   Bennett  Female  Twitternation
# ..           ...      ...        ...       ...     ...            ...
# 245          968        4     Teresa  Reynolds  Female       Flashdog
# 246          969        3      Marie     Ortiz  Female          Meejo
# 247          977        7    Cynthia     Dixon  Female        Skalith
# 248          994        2   Clarence    Morgan    Male       Edgewire
# 249          996       10      Debra    Garcia  Female   Dazzlesphere
#
#                        Occupation
# 0                   Developer III
# 1     Mechanical Systems Engineer
# ...

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
week1.merge(customers, how = "left", left_on = "Customer ID", right_index = True).head(3)
# Out:
#    Customer ID  Food ID     ID First Name   Last Name  Gender     Company  \
# 0          537        9  538.0       Sara  Washington  Female      Skimia
# 1           97        4   98.0       Jean       Mills  Female  Fivebridge
# 2          658        1  659.0     Howard      Hudson    Male  Topicshots
#
#                    Occupation
# 0  Database Administrator III
# 1            Product Engineer
# 2                   Professor

# %%
satisfaction = pd.read_csv("Restaurant - Week 1 Satisfaction.csv")

# %%
len(satisfaction)
# Out:
# 250

# %%
satisfaction.head(3)
# Out:
#    Satisfaction Rating
# 0                    2
# 1                    7
# 2                    3

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
week1.merge(satisfaction, how = "inner", left_index = True, right_index = True ).head(3)
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3

# %%
week1.join(satisfaction).head(3)
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3

# %%
pd.merge(week1, customers, how = 'left', left_on = "Customer ID", right_on = "ID" )
# Out:
#      Customer ID  Food ID   ID First Name Last Name  Gender    Company  \
# 0            537        9  537     Cheryl   Carroll  Female   Zoombeat
# 1             97        4   97     Amanda   Watkins  Female        Ozu
# 2            658        1  658    Patrick      Webb    Male  Browsebug
# 3            202        2  202      Louis  Campbell    Male  Rhynoodle
# 4            155        9  155    Carolyn      Diaz  Female   Gigazoom
# ..           ...      ...  ...        ...       ...     ...        ...
# 245          413        9  413      Diane    Bailey  Female    Wikibox
# 246          926        6  926       Anne    Wagner  Female      Skyba
# 247          134        3  134      Diana      Hall  Female      Quinu
# 248          396        6  396       Juan    Romero    Male    Zoonder
# 249          535       10  535      Nancy       Cox  Female     Trudeo
#
#                         Occupation
# 0                 Registered Nurse
# 1              Account Coordinator
# ...

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
df4 = pd.DataFrame({'group': ['Accounting', 'Engineering', 'HR'],
                    'supervisor': ['Carly', 'Guido', 'Steve']})

# %%
import pandas as pd

# %%
df4 = pd.DataFrame({'group': ['Accounting', 'Engineering', 'HR'],
                    'supervisor': ['Carly', 'Guido', 'Steve']})

# %%
df5 = pd.DataFrame({'group': ['Accounting', 'Accounting',
                              'Engineering', 'Engineering', 'HR', 'HR'],
                    'skills': ['math', 'spreadsheets', 'coding', 'linux',
                               'spreadsheets', 'organization']})

# %%
df4
# Out:
#          group supervisor
# 0   Accounting      Carly
# 1  Engineering      Guido
# 2           HR      Steve

# %%
df5
# Out:
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreadsheets
# 5           HR  organization

# %%
df4.merge(df5, how = "left", on = "group")
# Out:
#          group supervisor        skills
# 0   Accounting      Carly          math
# 1   Accounting      Carly  spreadsheets
# 2  Engineering      Guido        coding
# 3  Engineering      Guido         linux
# 4           HR      Steve  spreadsheets
# 5           HR      Steve  organization

# %%
pd.merge(df5,df4, how = 'inner')
# Out:
#          group        skills supervisor
# 0   Accounting          math      Carly
# 1   Accounting  spreadsheets      Carly
# 2  Engineering        coding      Guido
# 3  Engineering         linux      Guido
# 4           HR  spreadsheets      Steve
# 5           HR  organization      Steve

# %%
df5.merge(df4, how = "left", on = "group")
# Out:
#          group        skills supervisor
# 0   Accounting          math      Carly
# 1   Accounting  spreadsheets      Carly
# 2  Engineering        coding      Guido
# 3  Engineering         linux      Guido
# 4           HR  spreadsheets      Steve
# 5           HR  organization      Steve

# %%
df4.merge(df5, how = "left", on = "group")
# Out:
#          group supervisor        skills
# 0   Accounting      Carly          math
# 1   Accounting      Carly  spreadsheets
# 2  Engineering      Guido        coding
# 3  Engineering      Guido         linux
# 4           HR      Steve  spreadsheets
# 5           HR      Steve  organization

# %%
import pandas as pd

# %%
fortune = pd.read_csv("fortune1000.csv")

# %%
sector = fortune.groupby(["Sector", "Industry"])

# %%
fortune.head(1)
# Out:
#    Rank  Company     Sector               Industry         Location  Revenue  \
# 0     1  Walmart  Retailing  General Merchandisers  Bentonville, AR   482130
#
#    Profits  Employees
# 0    14694    2300000

# %%
sector.head(100)
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
sector.get_group("Energy", "Retailing")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-feb75446d24d> in <module>
# ----> 1 sector.get_group("Energy", "Retailing")
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     676             obj = self._selected_obj
#     677
# --> 678         inds = self._get_index(name)
#     679         if not len(inds):
#     680             raise KeyError(name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _get_index(self, name)
#     489         Safe get index, translate keys for datelike to underlying repr.
#     490         """
# --> 491         return self._get_indices([name])[0]
#     492
#     493     @cache_readonly
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _get_indices(self, names)
#     463             if not isinstance(name_sample, tuple):
# ...

# %%
sector.get_group("Apparel")
# Out:
#      Rank               Company   Sector Industry             Location  \
# 90     91                  Nike  Apparel  Apparel        Beaverton, OR
# 230   231                    VF  Apparel  Apparel       Greensboro, NC
# 339   340                   PVH  Apparel  Apparel         New York, NY
# 353   354          Ralph Lauren  Apparel  Apparel         New York, NY
# 447   448           Hanesbrands  Apparel  Apparel    Winston-Salem, NC
# 546   547          Levi Strauss  Apparel  Apparel    San Francisco, CA
# 574   575                 Coach  Apparel  Apparel         New York, NY
# 596   597          Under Armour  Apparel  Apparel        Baltimore, MD
# 682   683          Fossil Group  Apparel  Apparel       Richardson, TX
# 694   695       Skechers U.S.A.  Apparel  Apparel  Manhattan Beach, CA
# 725   726              Carter’s  Apparel  Apparel          Atlanta, GA
# 793   794  Wolverine World Wide  Apparel  Apparel         Rockford, MI
# ...

# %%
sector['Revenue', 'Profits'].sum()
# Out:
#                                                                    Revenue  \
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                           357940
# Apparel             Apparel                                          95968
# Business Services   Advertising, marketing                           22748
#                     Diversified Outsourcing Services                 64829
#                     Education                                         7485
# ...                                                                    ...
# Transportation      Trucking, Truck Leasing                          35950
# Wholesalers         Miscellaneous                                     8982
#                     Wholesalers: Diversified                        176138
#                     Wholesalers: Electronics and Office Equipment   147906
#                     Wholesalers: Food and Grocery                   111774
#
# ...

# %%
sector['Employees'].mean()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            48402.850000
# Apparel              Apparel                                          23093.133333
# Business Services    Advertising, marketing                           62050.000000
#                      Diversified Outsourcing Services                 50595.000000
#                      Education                                        15585.000000
#                                                                           ...
# Transportation       Trucking, Truck Leasing                          18939.555556
# Wholesalers          Miscellaneous                                     9200.000000
#                      Wholesalers: Diversified                          9353.240000
#                      Wholesalers: Electronics and Office Equipment    20832.625000
#                      Wholesalers: Food and Grocery                    19317.500000
# ...

# %%
sector.agg({'Revenue': 'sum', 'Employees': 'sum'})
# Out:
#                                                                    Revenue  \
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                           357940
# Apparel             Apparel                                          95968
# Business Services   Advertising, marketing                           22748
#                     Diversified Outsourcing Services                 64829
#                     Education                                         7485
# ...                                                                    ...
# Transportation      Trucking, Truck Leasing                          35950
# Wholesalers         Miscellaneous                                     8982
#                     Wholesalers: Diversified                        176138
#                     Wholesalers: Electronics and Office Equipment   147906
#                     Wholesalers: Food and Grocery                   111774
#
# ...

# %%
sector.agg(['sum', 'size', 'mean'])
# Out:
#                                                                     Rank       \
#                                                                      sum size
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                           8870   20
# Apparel             Apparel                                         8757   15
# Business Services   Advertising, marketing                           541    2
#                     Diversified Outsourcing Services                9015   14
#                     Education                                       2550    3
# ...                                                                  ...  ...
# Transportation      Trucking, Truck Leasing                         5772    9
# Wholesalers         Miscellaneous                                    315    1
#                     Wholesalers: Diversified                       12922   25
#                     Wholesalers: Electronics and Office Equipment   2241    8
# ...

# %%
sector.size()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            20
# Apparel              Apparel                                          15
# Business Services    Advertising, marketing                            2
#                      Diversified Outsourcing Services                 14
#                      Education                                         3
#                                                                       ..
# Transportation       Trucking, Truck Leasing                           9
# Wholesalers          Miscellaneous                                     1
#                      Wholesalers: Diversified                         25
#                      Wholesalers: Electronics and Office Equipment     8
#                      Wholesalers: Food and Grocery                     6
# Length: 79, dtype: int64

# %%
cities = fortune.groupby("Location")

# %%
cities

# %%
df = pd.DataFrame(columns = fortune.columns)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Rank, Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
for city, data in cities:
    largest_cities = data.nlargest(1, "Revenue")
    df = df.append(largest_cities)

# %%
df
# Out:
#     Rank                   Company                        Sector  \
# 137  138       Abbott Laboratories                   Health Care
# 168  169    Goodyear Tire & Rubber        Motor Vehicles & Parts
# 287  288  Air Products & Chemicals                     Chemicals
# 829  830     Benchmark Electronics                    Technology
# 373  374    Casey’s General Stores                     Retailing
# ..   ...                       ...                           ...
# 6      7                CVS Health          Food and Drug Stores
# 505  506   Hanover Insurance Group                    Financials
# 763  764      Penn National Gaming  Hotels, Resturants & Leisure
# 772  773            Bon-Ton Stores                     Retailing
# 931  932             Herman Miller            Household Products
#
#                                            Industry         Location Revenue  \
# 137                  Medical Products and Equipment  Abbott Park, IL   20661
# ...

# %%
fortune["Location"]
# Out:
# 0        Bentonville, AR
# 1             Irving, TX
# 2          Cupertino, CA
# 3              Omaha, NE
# 4      San Francisco, CA
#              ...
# 995         Westbury, NY
# 996         Portland, OR
# 997         Portland, OR
# 998           Dublin, OH
# 999        Wauwatosa, WI
# Name: Location, Length: 1000, dtype: object
